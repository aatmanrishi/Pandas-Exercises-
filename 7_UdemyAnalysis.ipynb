# %% [markdown]
# Importing Required Libraries

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read Data From File

# %%
df = pd.read_csv('udemy_courses.csv');

# %% [markdown]
# Display Top 10 Rows And Bottom 10 Rows

# %%
print(df.head());
print(df.tail());
# Out:
#    course_id                                       course_title
# 0    1070968                 Ultimate Investment Banking Course  \
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200  \
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level
# 0             2147           23            51          All Levels  \
# ...

# %% [markdown]
# Fidn The Sahpe Of Our Dataset

# %%
print(df.shape)
# Out:
# (3678, 12)

# %% [markdown]
# Getting the information of our dataset

# %%
print(df.info());
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB
# None

# %% [markdown]
# Check The Null Values In Dataset

# %%
print(df.isnull().sum());
# Another method that we can use to see that if there are any null values or not 
print(df.isnull().values.any());
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64
# False

# %% [markdown]
# Let's also make a historgram to see that if there are any nul values or not ?

# %%
sns.heatmap(df.isnull());

# %% [markdown]
# Check for Duplicates and Drop them

# %%
dup = df.duplicated().any();
print(dup);
df.drop_duplicates()
# Out:
# True
#       course_id                                       course_title
# 0       1070968                 Ultimate Investment Banking Course  \
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200  \
# ...

# %% [markdown]
# Find out the number of course per Subejects

# %%
print(df.columns);
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
print(df["subject"].value_counts());
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %% [markdown]
# Represetn the number of courses persubject

# %%
print(df["subject"].dtype)
# Check for the presence of NaN values in the column
print(df['subject'].isna().sum());
sns.histplot(data=df["subject"])
# Out:
# object
# 0
# <Axes: xlabel='subject', ylabel='Count'>

# %% [markdown]
# For which level udemy is providing courses

# %%
print(df.columns)
print(df['level'].unique());
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')
# ['All Levels' 'Intermediate Level' 'Beginner Level' 'Expert Level']

# %% [markdown]
# Now if we want to find number of couserses per level udemy is providing

# %%
print(df['level'].value_counts());
# Out:
# level
# All Levels            1929
# Beginner Level        1270
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %% [markdown]
# Getting a Visual Insights of the graph

# %%
sns.countplot(df,x='level')
plt.xlabel("Levels",fontsize=13)
plt.ylabel("No of Courses Per Level",fontsize=13)
plt.xticks(rotation=65);
plt.show();

# %% [markdown]
# Display the count of paid and free courses

# %%
print(df.columns)
print(df["is_paid"].value_counts());
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')
# is_paid
# True     3368
# False     310
# Name: count, dtype: int64

# %% [markdown]
# Creating Visual of Paid and Unpaid Courses

# %%
sns.countplot(data=df, x='is_paid', hue='is_paid')
plt.xlabel('Course Type')
plt.ylabel('Number of Courses')# Create a stacked countplot with hue
sns.countplot(data=df, x='is_paid', hue='is_paid')

# Set x and y labels
plt.xlabel('Course Type')
plt.ylabel('Number of Courses')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\AC\Desktop\CompleteFolder Set\DataAnalystCompletePythonRevision\Python Data Analytics Project Folder\5_PandasExericse\7_UdemyAnalysis.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/AC/Desktop/CompleteFolder%20Set/DataAnalystCompletePythonRevision/Python%20Data%20Analytics%20Project%20Folder/5_PandasExericse/7_UdemyAnalysis.ipynb#X55sZmlsZQ%3D%3D?line=0'>1</a> sns.countplot(data=df, x='is_paid', hue='is_paid')
#       <a href='vscode-notebook-cell:/c%3A/Users/AC/Desktop/CompleteFolder%20Set/DataAnalystCompletePythonRevision/Python%20Data%20Analytics%20Project%20Folder/5_PandasExericse/7_UdemyAnalysis.ipynb#X55sZmlsZQ%3D%3D?line=1'>2</a> plt.xlabel('Course Type')
# ...

# %% [markdown]
# Which Course has more lectures free or paid

# %%
print(df.groupby(['is_paid'])['num_lectures'].mean());#Not working as expected  
# getting an error
# Out:
# is_paid
# False    21.416129
# True     41.829276
# Name: num_lectures, dtype: float64

# %% [markdown]
# Which Courses have a higher number of subscribers?

# %%
df.groupby('is_paid')['num_subscribers'].mean()
# Out:
# is_paid
# False    11533.951613
# True      2429.808492
# Name: num_subscribers, dtype: float64

# %% [markdown]
# Which level course has highes number of subscribers ?

# %%
print(df.groupby('level')['num_subscribers'].mean())
# Out:
# level
# All Levels            3584.798341
# Beginner Level        3190.427559
# Expert Level           865.448276
# Intermediate Level    1762.482185
# Name: num_subscribers, dtype: float64

# %% [markdown]
# Find the most popular Course Title

# %% [markdown]
# Here we'll find most popular course title using two ways :

# %%
# Method 1
index_of_channel_having_max_subs = df['num_subscribers'].idxmax() ;
most_popular_course = df.loc[index_of_channel_having_max_subs,'course_title'];
# print(most_popular_course);
print('\n')
# print(df[df['num_subscribers'].max()==df['num_subscribers']])

#Method 2
print(df[df['num_subscribers'].max()==df['num_subscribers']]['course_title'])
# Out:
# 2827    Learn HTML5 Programming From Scratch
# Name: course_title, dtype: object

# %% [markdown]
# Display 10 Most Popular Courses as per number of subscribers

# %%
print(df.columns)
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
print(df.loc[df['num_subscribers'].sort_values(ascending=False).head(10).index,'course_title'])
# Out:
# 2827                 Learn HTML5 Programming From Scratch
# 3032                       Coding for Entrepreneurs Basic
# 3230                           The Web Developer Bootcamp
# 2783    Build Your First Website in 1 Week with HTML5 ...
# 3232                The Complete Web Developer Course 2.0
# 1896                Free Beginner Electric Guitar Lessons
# 2589    Web Design for Web Developers: Build Beautiful...
# 2619               Learn Javascript & JQuery From Scratch
# 3289    Practical PHP: Master the Basics and Code Dyna...
# 3247            JavaScript: Understanding the Weird Parts
# Name: course_title, dtype: object

# %% [markdown]
# Another way to solve this question

# %%
top_10= df.sort_values(by="num_subscribers",ascending=False).head(10)

# %%
sns.barplot(x="num_subscribers",y="course_title",data=top_10);
plt.show()

# %% [markdown]
# Find the course which is having the highesh number of reviews.

# %%
print(df['num_reviews'].dtype);
print(df[df['num_reviews'].max() == df['num_reviews']]['course_title'])
# Out:
# int64
# 3230    The Web Developer Bootcamp
# Name: course_title, dtype: object

# %% [markdown]
# Does Price Effect the Reviews

# %%
sns.scatterplot(x='price',y='num_reviews',data=df)
plt.show();

# %% [markdown]
# Find the total number of course realted to python

# %%
print(df['course_title'].str.contains('python',case=False).sum())
# Out:
# 29

# %% [markdown]
# Display 10 Most Popular Python Courses As Per Number Of Subscribers

# %%
print(print(df[df['course_title'].str.contains('python',case=False)].sort_values(by="num_subscribers",ascending=False).head(10)['course_title']));
# Out:
# 2497                          Web Programming with Python
# 2570    Coding for Entrepreneurs: Learn Python, Django...
# 2528          Learn Python and Django: Payment Processing
# 3200    Python and Django Full Stack Web Developer Boo...
# 3507    Fun and creative web engineering with Python a...
# 2553    The Complete Ethical Hacking Course 2.0: Pytho...
# 3138    Complete Python Web Course: Build 8 Python Web...
# 3197    Try Django 1.9 | Build a Blog and Learn Python...
# 2681    Python for Beginners: Python Programming Langu...
# 3203                      REST APIs with Flask and Python
# Name: course_title, dtype: object
# None

# %% [markdown]
# In which year the highest number of courses wer posted ?

# %%
print(df.columns)
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
get_year_data = df['published_timestamp'].str.split('-').str[0];
df['year_coursePublished'] = get_year_data ; 
print(df['year_coursePublished'].value_counts());
# Out:
# year_coursePublished
# 2016    1206
# 2015    1014
# 2017     715
# 2014     491
# 2013     202
# 2012      45
# 2011       5
# Name: count, dtype: int64

# %% [markdown]
# Display the category wise count of posted subjects [Year wise ]

# %%
print(df.columns)
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject',
#        'year_coursePublished'],
#       dtype='object')

# %%
get_year_data = df['published_timestamp'].str.split('-').str[0];
df['year_coursePublished'] = get_year_data ; 
print(df.groupby('year_coursePublished')['subject'].value_counts());
# Out:
# year_coursePublished  subject
# 2011                  Web Development          5
# 2012                  Web Development         19
#                       Musical Instruments     10
#                       Graphic Design          10
#                       Business Finance         6
# 2013                  Business Finance        84
#                       Web Development         56
#                       Musical Instruments     39
#                       Graphic Design          23
# 2014                  Business Finance       192
#                       Musical Instruments    120
#                       Web Development        113
#                       Graphic Design          66
# 2015                  Business Finance       339
#                       Web Development        336
#                       Musical Instruments    171
#                       Graphic Design         168
# 2016                  Web Development        448
# ...
